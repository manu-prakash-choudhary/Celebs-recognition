# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline
import pywt

# %%
img=cv2.imread('./test_images/Maria_Sharapova1.jpg')
plt.imshow(img)
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)  #image in gray has been created
plt.imshow(gray,cmap='gray')

face_cascade = cv2.CascadeClassifier("./cascades/haarcascade_frontalface_default.xml") 
eye_cascade = cv2.CascadeClassifier("./cascades/haarcascade_eye.xml")





faces = face_cascade.detectMultiScale(gray,1.3,5) #will wrtten array([x,y,w,h],int32)
eyes = eye_cascade.detectMultiScale(gray,1.3,5)
faces,eyes


x,y,w,h=faces[0]

#croppin the image
crpd_image=img[y:y+h,x:x+w]

cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
for (ex,ey,ew,eh) in eyes:
    cv2.rectangle(img,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)

plt.imshow(crpd_image,cmap='gray')
# Out:
# 2

# %%
face_cascade = cv2.CascadeClassifier("./cascades/haarcascade_frontalface_default.xml") 
eye_cascade = cv2.CascadeClassifier("./cascades/haarcascade_eye.xml")
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color
        
#testing with correct image
#img=get_cropped_image_if_2_eyes('./test_images/Maria_Sharapova1.jpg')
#plt.imshow(img)

#testing with fault image
a=get_cropped_image_if_2_eyes('./test_images/MariaSharapova2.webp')
print(a)
# Out:
# None

# %%
#creating cropped photo directory
path_to_data = "./datasets/"
path_to_cr_data = "./datasets/cropped/"

import os
img_dirs = []  #list of all celebs
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)


img_dirs
# Out:
# ['./datasets/lionel_messi',
#  './datasets/maria_sharapova',
#  './datasets/roger_federer',
#  './datasets/serena_williams',
#  './datasets/virat_kohli']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        print(entry.path)
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            #if not os.path.exists(cropped_folder):
                #os.makedirs(cropped_folder)
                #cropped_image_dirs.append(cropped_folder)
                #print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            #cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# lionel_messi
# ./datasets/lionel_messi\A Genius in Full Bloom_ Lionel Messi....jpg
# ./datasets/lionel_messi\Barcelona Captain Lionel Messi Has....jpg
# ./datasets/lionel_messi\Barcelona face Bayern Munich again....jpg
# ./datasets/lionel_messi\Barcelona find a perfect Lionel Messi....jpeg
# ./datasets/lionel_messi\Barcelona President explains why Lionel....webp
# ./datasets/lionel_messi\Barcelona wants to keep Lionel Messi....jpg
# ./datasets/lionel_messi\Champions League glory with new club PSG.jpg
# ./datasets/lionel_messi\Comparing Lionel Messi and Pele_s....jpg
# ./datasets/lionel_messi\Estadio Leo Messi_ Fan Pays Heartfelt....jpeg
# ./datasets/lionel_messi\FFP flexibility needed says Barca chief....jpg
# ./datasets/lionel_messi\Five things on Lionel Messi.jpg
# ./datasets/lionel_messi\future of Lionel Messi....jpg
# ./datasets/lionel_messi\hat-trick as Argentina rout Bolivia....jpg
# ./datasets/lionel_messi\his Paris Saint Germain debut against Reims.jpg
# ./datasets/lionel_messi\Keylor Navas on Lionel Messi_ _He_s got....jpg
# ./datasets/lionel_messi\La Liga website removes Lionel Messi....jpg
# ./datasets/lionel_messi\La Liga_ Lionel Messi Considering Other....webp
# ./datasets/lionel_messi\Leo Messi (_WeAreMessi) _ Twitter (1).jpg
# ./datasets/lionel_messi\Leo Messi not staying at FC Barcelona.jpg
# ./datasets/lionel_messi\Leo Messi(_WeAreMessi) _ Twitter.jpg
# ./datasets/lionel_messi\Lionel Messi - Player profile 21_22....jpg
# ./datasets/lionel_messi\Lionel Messi - Stats_ Family & Facts... (1).jpg
# ./datasets/lionel_messi\Lionel Messi - Stats_ Family & Facts....jpg
# ./datasets/lionel_messi\Lionel Messi - Wikipedia.jpg
# ./datasets/lionel_messi\Lionel Messi agrees Barcelona contract....jpeg
# ./datasets/lionel_messi\Lionel Messi agrees to stay at....jpg
# ./datasets/lionel_messi\Lionel Messi and Barcelona agree to new....jpg
# ./datasets/lionel_messi\Lionel Messi backs English football_s....jpg
# ./datasets/lionel_messi\Lionel Messi Barcelona Contract Updates....jpg
# ./datasets/lionel_messi\Lionel Messi Barcelona contract....jpg
# ./datasets/lionel_messi\Lionel Messi becomes a free agent as....jpg
# ./datasets/lionel_messi\Lionel Messi brought calmness to PSG on....jpg
# ./datasets/lionel_messi\Lionel Messi chase....jpg
# ./datasets/lionel_messi\Lionel Messi Contract Tomorrow.jpg
# ./datasets/lionel_messi\Lionel Messi exit continues to hurt....jpg
# ./datasets/lionel_messi\Lionel Messi gets mobbed by hundreds of....jpg
# ./datasets/lionel_messi\Lionel Messi Is Leaving Barcelona_ and....jpeg
# ./datasets/lionel_messi\Lionel Messi is the best player in FIFA....jpg
# ./datasets/lionel_messi\Lionel Messi leaving Barcelona after....jpg
# ./datasets/lionel_messi\Lionel Messi makes a decision on his....jpeg
# ./datasets/lionel_messi\Lionel Messi makes PSG debut as Kylian....webp
# ./datasets/lionel_messi\Lionel Messi may have played final....jpg
# ./datasets/lionel_messi\Lionel Messi May Play at Inter Miami in....webp
# ./datasets/lionel_messi\Lionel Messi next club_ Where will the....jpg
# ./datasets/lionel_messi\Lionel Messi Obliges Reims Goalkeeper_s....jpg
# ./datasets/lionel_messi\Lionel Messi odds_ Could he play in MLS....jpg
# ./datasets/lionel_messi\Lionel Messi returns to Barcelona....jpg
# ./datasets/lionel_messi\Lionel Messi Rumors_ Manchester City....jpg
# ./datasets/lionel_messi\Lionel Messi Says He Will Stay With....jpg
# ./datasets/lionel_messi\Lionel Messi suspended 2 matches for....jpg
# ./datasets/lionel_messi\Lionel Messi to decide Barcelona future....jpg
# ./datasets/lionel_messi\Lionel Messi to exit Barcelona after 18....webp
# ./datasets/lionel_messi\Lionel Messi To Leave FC Barcelona_ The....jpg
# ./datasets/lionel_messi\Lionel Messi to sign new five-year deal....jpg
# ./datasets/lionel_messi\Lionel Messi Will Not Continue at....jpg
# ./datasets/lionel_messi\Lionel Messi Will Not End His Career at....webp
# ./datasets/lionel_messi\Lionel Messi will part ways with Barcelona.jpg
# ./datasets/lionel_messi\Lionel Messi would like to play in US....jpg
# ./datasets/lionel_messi\Lionel Messi _ Biography_ Team... (1).jpg
# ./datasets/lionel_messi\Lionel Messi _ Biography_ Team....jpg
# ./datasets/lionel_messi\Lionel MESSI _ Olympics.com.jpg
# ./datasets/lionel_messi\Lionel Messi _Wants to Stay_ at....jpg
# ./datasets/lionel_messi\Lionel Messi....jpeg
# ./datasets/lionel_messi\Lionel Messi.jpg
# ./datasets/lionel_messi\Lionel Messi_ Barcelona Scrambling to....jpg
# ./datasets/lionel_messi\Lionel Messi_ furious with contract....jpg
# ./datasets/lionel_messi\Lionel Messi_ Paris Saint-Germain....jpg
# ./datasets/lionel_messi\Lionel Messi_ The Greatest (2020) - IMDb.jpg
# ./datasets/lionel_messi\Lionel Messi_ World-Renowned Soccer Player.png
# ./datasets/lionel_messi\Lionel Messi_s Contract With Barcelona....jpg
# ./datasets/lionel_messi\Messi Barcelona deal reportedly extends....jpg
# ./datasets/lionel_messi\Messi contract saga goes to the wire....jpg
# ./datasets/lionel_messi\offer a blockbuster deal to Lionel Messi.jpeg
# ./datasets/lionel_messi\Paris May Destroy Barcelona....jpeg
# ./datasets/lionel_messi\Paris Saint-Germain....jpg
# ./datasets/lionel_messi\Pep Guardiola avoiding thoughts of....jpg
# ./datasets/lionel_messi\Pep Guardiola leaves Manchester City....jpg
# ./datasets/lionel_messi\PSG boss Mauricio Pochettino relishing....jpg
# ./datasets/lionel_messi\Sergio Busquets Shocked By Lionel Messi....webp
# ./datasets/lionel_messi\Soccer superstar Lionel Messi leaving....jpg
# ./datasets/lionel_messi\Tearful Lionel Messi bids farewell to....jpg
# ./datasets/lionel_messi\The Life of Lionel Messi _ Brut..jpg
# ./datasets/lionel_messi\Top Soccer Players_ to Leave Barcelona....jpg
# ./datasets/lionel_messi\Transfer news - Where does Lionel Messi....jpg
# maria_sharapova
# ./datasets/maria_sharapova\74_254 Maria Sharapova Photos and....jpg
# ./datasets/maria_sharapova\action against Serena Williams....jpg
# ./datasets/maria_sharapova\Australian Open 2019_ Maria Sharapova....webp
# ./datasets/maria_sharapova\Australian Open 2020_ Maria Sharapova_s....jpg
# ./datasets/maria_sharapova\COVID-19_ Maria Sharapova recalls fun....jpg
# ./datasets/maria_sharapova\distraction__ Maria Sharapova....jpg
# ./datasets/maria_sharapova\Exclusive.jpg
# ./datasets/maria_sharapova\Five-time Grand Slam champion Maria....jpg
# ./datasets/maria_sharapova\Five-time Grand Slam winner Maria....jpg
# ./datasets/maria_sharapova\Flickr - Carine06 - Maria Sharapova....jpg
# ./datasets/maria_sharapova\Goodbye_ tennis_ Maria Sharapova....jpg
# ./datasets/maria_sharapova\Is Maria Sharapova married_ Know all....jpeg
# ./datasets/maria_sharapova\Know Sachin Tendulkar & India Went Berserk.jpeg
# ./datasets/maria_sharapova\Maria Sharapova (1).jpg
# ./datasets/maria_sharapova\Maria Sharapova (Contributor of Tribe....jpg
# ./datasets/maria_sharapova\Maria Sharapova (Tennis Player) - On....jpg
# ./datasets/maria_sharapova\Maria Sharapova (_MariaSharapova) _ Twitter.jpg
# ./datasets/maria_sharapova\Maria Sharapova - Age_ Height & Tennis... (1).jpg
# ./datasets/maria_sharapova\Maria Sharapova - Age_ Height & Tennis....jpg
# ./datasets/maria_sharapova\Maria Sharapova - IMDb.jpg
# ./datasets/maria_sharapova\Maria Sharapova - Wikimedia Commons.jpg
# ./datasets/maria_sharapova\Maria Sharapova - Wikipedia.jpg
# ./datasets/maria_sharapova\Maria Sharapova announces retirement... (1).jpg
# ./datasets/maria_sharapova\Maria Sharapova announces retirement....jpg
# ./datasets/maria_sharapova\Maria Sharapova Beauty....jpg
# ./datasets/maria_sharapova\Maria Sharapova career statistics....jpg
# ./datasets/maria_sharapova\Maria Sharapova cautions young WTA....jpg
# ./datasets/maria_sharapova\Maria Sharapova considered _Sugarpova....jpg
# ./datasets/maria_sharapova\Maria Sharapova editorial stock image....jpg
# ./datasets/maria_sharapova\Maria Sharapova handed Italian Open....jpg
# ./datasets/maria_sharapova\Maria Sharapova is impressed by her own....jpg
# ./datasets/maria_sharapova\Maria Sharapova Leaves A Storied Legacy.jpg
# ./datasets/maria_sharapova\Maria Sharapova Net Worth_ a Look at....jpg
# ./datasets/maria_sharapova\Maria Sharapova on Remembering to Wear....jpg
# ./datasets/maria_sharapova\Maria Sharapova on the Loves of Her....jpg
# ./datasets/maria_sharapova\Maria Sharapova on Twitter_ _Anyone....jpg
# ./datasets/maria_sharapova\Maria Sharapova Opens Up on New Chapter....jpg
# ./datasets/maria_sharapova\Maria Sharapova reacts after being....webp
# ./datasets/maria_sharapova\Maria Sharapova retires at 32....jpg
# ./datasets/maria_sharapova\Maria Sharapova retires from tennis -.jpeg
# ./datasets/maria_sharapova\Maria Sharapova retires from tennis... (1).jpg
# ./datasets/maria_sharapova\Maria Sharapova Retires From Tennis....jpg
# ./datasets/maria_sharapova\Maria Sharapova Retires_ Her Best....jpg
# ./datasets/maria_sharapova\Maria Sharapova returns to action in....jpg
# ./datasets/maria_sharapova\Maria Sharapova Sad While Revealing....jpeg
# ./datasets/maria_sharapova\Maria Sharapova shares the success....jpg
# ./datasets/maria_sharapova\Maria Sharapova Signs on as the New....jpg
# ./datasets/maria_sharapova\Maria Sharapova to be reinstated as UN....jpg
# ./datasets/maria_sharapova\Maria Sharapova to return from five....jpg
# ./datasets/maria_sharapova\Maria Sharapova US Open 2015 - Maria....jpg
# ./datasets/maria_sharapova\Maria Sharapova Wants to Be Clear_ She....jpg
# ./datasets/maria_sharapova\Maria Sharapova will go down as one of....jpg
# ./datasets/maria_sharapova\Maria Sharapova _ Biography_ Grand Slam... (1).jpg
# ./datasets/maria_sharapova\Maria Sharapova _ Biography_ Grand Slam....jpg
# ./datasets/maria_sharapova\Maria Sharapova _ Player Stats & More....jpg
# ./datasets/maria_sharapova\Maria Sharapova _ Tennis Pro and....jpg
# ./datasets/maria_sharapova\Maria Sharapova _legend with mind of....jpg
# ./datasets/maria_sharapova\Maria Sharapova _Made an Honest Mistake....jpg
# ./datasets/maria_sharapova\Maria Sharapova _ready to achieve new....jpg
# ./datasets/maria_sharapova\Maria Sharapova....jpg
# ./datasets/maria_sharapova\Maria Sharapova.jpg
# ./datasets/maria_sharapova\Maria Sharapova_ A complicated tennis....webp
# ./datasets/maria_sharapova\Maria Sharapova_ Net worth_ Family And....jpg
# ./datasets/maria_sharapova\Maria Sharapova_ Tennis player....jpg
# ./datasets/maria_sharapova\Maria Sharapova_ What Is The Former....jpg
# ./datasets/maria_sharapova\Maria Sharapova_ When you come from....jpg
# ./datasets/maria_sharapova\Maria Sharapova_ who the tennis player....jpg
# ./datasets/maria_sharapova\Maria Sharapova_ _That_s why I never....jpg
# ./datasets/maria_sharapova\Maria Sharapova_ _When I won Wimbledon....jpg
# ./datasets/maria_sharapova\Peers hail _mind of a champion__ Maria....jpg
# ./datasets/maria_sharapova\Photos_ Maria Sharapova through the... (1).jpg
# ./datasets/maria_sharapova\Photos_ Maria Sharapova through the....jpg
# ./datasets/maria_sharapova\returning to tennis after doping ban....jpg
# ./datasets/maria_sharapova\Sports Illustrated Swimsuit Photos.jpg
# ./datasets/maria_sharapova\Tag Heuer cut ties with Maria Sharapova....jpg
# ./datasets/maria_sharapova\tennis doping ban return nears....jpg
# ./datasets/maria_sharapova\Tennis Star Maria Sharapova Announces... (1).jpg
# ./datasets/maria_sharapova\Tennis Star Maria Sharapova Announces....jpg
# ./datasets/maria_sharapova\Tennis star Maria Sharapova hangs up....jpg
# ./datasets/maria_sharapova\The controversial career of Maria....jpg
# ./datasets/maria_sharapova\These stunning pictures of former....jpg
# ./datasets/maria_sharapova\Who Is Maria Sharapova_ 5 Things To....jpg
# ./datasets/maria_sharapova\Wimbledon 2019_ Maria Sharapova Knocked....webp
# ./datasets/maria_sharapova\You Dope Like Maria Sharapova.jpg
# roger_federer
# ./datasets/roger_federer\73 Questions With Roger Federer _ Vogue....jpg
# ./datasets/roger_federer\Analysis_ Yes_ Roger Federer won_ what....jpg
# ./datasets/roger_federer\asserts Slam champion on Federer injury....jpg
# ./datasets/roger_federer\ATP roundup_ Roger Federer victorious....jpg
# ./datasets/roger_federer\Balinda Bencic_ _I am very positive....jpg
# ./datasets/roger_federer\Before they were stars_ Roger Federer.jpg
# ./datasets/roger_federer\career achievements by Roger Federer....jpg
# ./datasets/roger_federer\Federer after Murray calls his game....png
# ./datasets/roger_federer\Federer highest-earning tennis player....jpg
# ./datasets/roger_federer\Federer wants to play again_ but....jpg
# ./datasets/roger_federer\Five classic Roger Federer matches....jpg
# ./datasets/roger_federer\French Open_ Roger Federer withdraws....jpg
# ./datasets/roger_federer\Fresh doubts over Roger Federer_s....jpg
# ./datasets/roger_federer\future in doubt after US Open withdrawal.jpg
# ./datasets/roger_federer\Happy Birthday Roger Federer_ A look at... (1).webp
# ./datasets/roger_federer\Happy Birthday Roger Federer_ A look at....webp
# ./datasets/roger_federer\I just don_t want to see Roger Federer....jpg
# ./datasets/roger_federer\Kyrgios_ _Roger Federer is more....jpg
# ./datasets/roger_federer\never loved tennis like Roger Federer....jpg
# ./datasets/roger_federer\OMG_ Roger Federer Withdraws From....jpg
# ./datasets/roger_federer\On this train until Wimbledon__ says....webp
# ./datasets/roger_federer\opponent ditched Roger Federer tactic....jpg
# ./datasets/roger_federer\Roger Federer - Wife_ Children & Titles....jpg
# ./datasets/roger_federer\Roger Federer - Wikipedia.jpg
# ./datasets/roger_federer\Roger Federer Announces Return from....jpg
# ./datasets/roger_federer\Roger Federer Best Shots Wimbledon 2021....jpg
# ./datasets/roger_federer\Roger Federer Debuts His First Sneaker....jpg
# ./datasets/roger_federer\Roger Federer Donating _1 Million to....jpg
# ./datasets/roger_federer\Roger Federer finds his rhythm_ reaches....jpeg
# ./datasets/roger_federer\Roger Federer knee surgery could mark....jpg
# ./datasets/roger_federer\Roger Federer needs another knee....jpg
# ./datasets/roger_federer\Roger Federer on Twitter_ _The....jpg
# ./datasets/roger_federer\Roger Federer pulls out of French Open... (1).jpg
# ./datasets/roger_federer\Roger Federer pulls out of French Open... (2).jpg
# ./datasets/roger_federer\Roger Federer pulls out of French Open... (3).jpg
# ./datasets/roger_federer\Roger Federer pulls out of French Open....jpeg
# ./datasets/roger_federer\Roger Federer Pulls Out of French Open....jpg
# ./datasets/roger_federer\Roger Federer quits the French Open due....jpeg
# ./datasets/roger_federer\Roger Federer Reacts After Becoming....webp
# ./datasets/roger_federer\Roger Federer says he is unsure whether....jpg
# ./datasets/roger_federer\Roger Federer says timing of return to....webp
# ./datasets/roger_federer\Roger Federer set to return in March....jpeg
# ./datasets/roger_federer\Roger Federer tops Forbes_ list of top....jpg
# ./datasets/roger_federer\Roger Federer turns 40 with career at....jpg
# ./datasets/roger_federer\Roger Federer Updates Fans on a....jpg
# ./datasets/roger_federer\Roger Federer upset in straight sets at....jpeg
# ./datasets/roger_federer\Roger Federer was very genuinely happy....jpg
# ./datasets/roger_federer\Roger Federer Withdraws from 2021....jpg
# ./datasets/roger_federer\Roger Federer withdraws from Australian... (1).jpg
# ./datasets/roger_federer\Roger Federer withdraws from Australian....jpg
# ./datasets/roger_federer\Roger Federer withdraws from French... (1).jpg
# ./datasets/roger_federer\Roger Federer Withdraws from French....jpg
# ./datasets/roger_federer\Roger Federer Withdraws From French....webp
# ./datasets/roger_federer\Roger Federer withdraws from Tokyo....jpg
# ./datasets/roger_federer\Roger Federer Withdraws From Tokyo....webp
# ./datasets/roger_federer\Roger Federer _ Biography... (1).jpg
# ./datasets/roger_federer\Roger Federer _ Biography....jpg
# ./datasets/roger_federer\Roger Federer _ Overview _ ATP Tour....jpg
# ./datasets/roger_federer\Roger Federer _dancing On Clouds And....jpeg
# ./datasets/roger_federer\Roger Federer _may not come back_ as....jpg
# ./datasets/roger_federer\Roger Federer-aligned Swiss Sneaker....webp
# ./datasets/roger_federer\Roger Federer-Backed Swiss Shoemaker On....jpg
# ./datasets/roger_federer\Roger Federer. La biografa definitiva ....jpg
# ./datasets/roger_federer\Roger Federer_ Biography_ Career....webp
# ./datasets/roger_federer\Roger Federer_ Cristiano Ronaldo And....jpg
# ./datasets/roger_federer\Roger Federer_ out of Australian Open....jpg
# ./datasets/roger_federer\Roger Federer_ Serena Williams....jpg
# ./datasets/roger_federer\Roger Federer_ Swiss star pulls out of....jpg
# ./datasets/roger_federer\Roger Federer_ _I don_t see a....jpg
# ./datasets/roger_federer\Roger Federer_ _I stopped 12 years ago....jpg
# ./datasets/roger_federer\Roger Federer_ _I_m a bit of a scaredy cat_.jpg
# ./datasets/roger_federer\Roger Federer_s team are the secret to....jpg
# ./datasets/roger_federer\Roger Federer_s Tokyo Olympics....jpg
# ./datasets/roger_federer\Rolex and Roger Federer - Every Rolex... (1).webp
# ./datasets/roger_federer\Rolex and Roger Federer - Every Rolex....webp
# ./datasets/roger_federer\says Roger Federer who....jpg
# ./datasets/roger_federer\Setback for Roger Federer ahead of....webp
# ./datasets/roger_federer\Seven times Roger Federer showed nerves....jpg
# ./datasets/roger_federer\Tennis ace Roger Federer says return....webp
# ./datasets/roger_federer\Tennis_ Roger Federer withdraws from... (1).jpg
# ./datasets/roger_federer\Tennis_ Roger Federer withdraws from....jpg
# ./datasets/roger_federer\The General Joy of Roger Federer....jpg
# ./datasets/roger_federer\Tokyo Olympics after Wimbledon _ Tennis....jpg
# ./datasets/roger_federer\Tokyo Olympics _ Roger Federer....jpg
# ./datasets/roger_federer\US Open 2021_ Roger Federer Says Return....webp
# ./datasets/roger_federer\Why did Roger Federer retire from the....jpg
# ./datasets/roger_federer\Wimbledon 2021_ Federer declares he is....jpg
# ./datasets/roger_federer\Wimbledon draw_ Tough path ahead for....jpg
# ./datasets/roger_federer\Wimbledon_ Roger Federer Crashes Out....webp
# serena_williams
# ./datasets/serena_williams\2014 Serena Williams tennis season....jpg
# ./datasets/serena_williams\At the French Open_ Serena Williams Is....jpg
# ./datasets/serena_williams\Australian Open_ Serena Williams....jpg
# ./datasets/serena_williams\can afford Serena Williams_ gamer chair....jpg
# ./datasets/serena_williams\Happy Birthday Serena Williams_ Career....webp
# ./datasets/serena_williams\Happy Birthday.jpg
# ./datasets/serena_williams\owning up to mistakes_ Serena Williams....jpg
# ./datasets/serena_williams\Serena and Venus Williams withdraw from....webp
# ./datasets/serena_williams\Serena Williams - Grace Hopper Celebration.jpg
# ./datasets/serena_williams\Serena Williams - Husband_ Daughter....jpg
# ./datasets/serena_williams\Serena Williams - News_ Tips & Guides....jpg
# ./datasets/serena_williams\Serena Williams - WHYY.jpg
# ./datasets/serena_williams\Serena Williams - Wikipedia.jpg
# ./datasets/serena_williams\Serena Williams and Her Fellow Tennis....jpg
# ./datasets/serena_williams\Serena Williams And Her New _Doubles....webp
# ./datasets/serena_williams\Serena Williams announces she will not....jpg
# ./datasets/serena_williams\Serena Williams best shots _ Australian....jpg
# ./datasets/serena_williams\Serena Williams Biography_ Achievements....jpg
# ./datasets/serena_williams\Serena Williams career statistics....jpg
# ./datasets/serena_williams\Serena Williams chasing more tennis....jpg
# ./datasets/serena_williams\Serena Williams crashes out of WTA top....jpg
# ./datasets/serena_williams\Serena Williams Dedicates Triumphant....jpg
# ./datasets/serena_williams\Serena Williams Drills_ Tips... (1).jpg
# ./datasets/serena_williams\Serena Williams Drills_ Tips....jpg
# ./datasets/serena_williams\Serena Williams Falls From Ankle Injury....jpg
# ./datasets/serena_williams\Serena Williams has experienced traumas....jpg
# ./datasets/serena_williams\Serena Williams Has Withdrawn from the....jpg
# ./datasets/serena_williams\Serena Williams hired diverse designers... (1).jpg
# ./datasets/serena_williams\Serena Williams hired diverse designers....jpg
# ./datasets/serena_williams\Serena Williams hitting partner on....jpg
# ./datasets/serena_williams\Serena Williams injury_ Six-time US....png
# ./datasets/serena_williams\Serena Williams is calling out sexism....jpg
# ./datasets/serena_williams\Serena Williams is positively glowing....jpg
# ./datasets/serena_williams\Serena Williams is the greatest and can....jpg
# ./datasets/serena_williams\Serena Williams Juggles Motherhood....jpg
# ./datasets/serena_williams\Serena Williams Left the Match But Not....png
# ./datasets/serena_williams\Serena Williams on Championing Young....jpg
# ./datasets/serena_williams\Serena Williams On Her Future_ _I....jpg
# ./datasets/serena_williams\Serena Williams on Her Latest Nike....jpg
# ./datasets/serena_williams\Serena Williams on how to handle naysayers.jpg
# ./datasets/serena_williams\Serena Williams on Self-Care_ Her....jpg
# ./datasets/serena_williams\Serena Williams Revealed as Buyerand....jpg
# ./datasets/serena_williams\Serena Williams Reveals Her Exact....jpg
# ./datasets/serena_williams\Serena Williams Says She Won_t Play at....jpg
# ./datasets/serena_williams\Serena Williams Thinks....jpg
# ./datasets/serena_williams\Serena Williams to play in Parma....jpg
# ./datasets/serena_williams\Serena Williams turned....webp
# ./datasets/serena_williams\Serena Williams turns heads in jaw....jpg
# ./datasets/serena_williams\Serena Williams vs Martina Hingis Full....jpg
# ./datasets/serena_williams\Serena Williams Withdraws From The U.S ....jpg
# ./datasets/serena_williams\Serena Williams withdraws from U.S ....jpg
# ./datasets/serena_williams\Serena Williams withdraws from US Open... (1).jpg
# ./datasets/serena_williams\Serena Williams withdraws from US Open... (2).jpg
# ./datasets/serena_williams\Serena Williams withdraws from US Open... (3).jpg
# ./datasets/serena_williams\Serena Williams withdraws from US Open....jpg
# ./datasets/serena_williams\Serena Williams withdraws from US Open.jpg
# ./datasets/serena_williams\Serena Williams withdraws from....webp
# ./datasets/serena_williams\Serena Williams _ Biography_ Titles... (1).jpg
# ./datasets/serena_williams\Serena Williams _ Biography_ Titles....jpg
# ./datasets/serena_williams\Serena Williams.jpg
# ./datasets/serena_williams\Serena Williams_ 100 Women of the Year....jpg
# ./datasets/serena_williams\Serena Williams_ Biography_ Career....webp
# ./datasets/serena_williams\Serena Williams_ coach on recovery from....jpg
# ./datasets/serena_williams\Serena Williams_ Daughter_ 4_ Teaches....jpg
# ./datasets/serena_williams\Serena Williams_ Diet And What She Eats....jpeg
# ./datasets/serena_williams\Serena Williams_ predicts Henman.jpg
# ./datasets/serena_williams\Serena Williams_ The Great One....jpg
# ./datasets/serena_williams\Serena Williams_ Venus Williams....jpg
# ./datasets/serena_williams\Serena_ Venus Williams both out of US....jpg
# ./datasets/serena_williams\sexist attacks_ Serena Williams....jpg
# ./datasets/serena_williams\Tennis_ Serena Williams withdraws from....png
# ./datasets/serena_williams\The legacy of Serena Williams _ UMKC....png
# ./datasets/serena_williams\US Open 2021_ Serena Williams can equal....jpg
# ./datasets/serena_williams\US open 2021_ Serena Williams withdraws....jpg
# ./datasets/serena_williams\US Open preview_ Approaching 40_ Serena....jpg
# ./datasets/serena_williams\US Open Tennis Championships....jpg
# ./datasets/serena_williams\US Open_ Why can_t Serena Williams win....jpg
# ./datasets/serena_williams\Watch Serena Williams at the U.S. Open ....jpg
# ./datasets/serena_williams\What next for Serena Williams after her....jpg
# ./datasets/serena_williams\Wimbledon 2021_ Serena Williams forced....jpg
# ./datasets/serena_williams\Wimbledon_ Serena Williams Retires In....jpg
# virat_kohli
# ./datasets/virat_kohli\10 Years Since Virat Kohli_s Test Debut....jpg
# ./datasets/virat_kohli\7 lesser known facts about Virat Kohli....jpg
# ./datasets/virat_kohli\ASCI to send notice to Virat Kohli over....webp
# ./datasets/virat_kohli\Buy DK Indian Icons _ Virat Kohli Book....jpg
# ./datasets/virat_kohli\Cricket_ Virat Kohli slump leads to....jpg
# ./datasets/virat_kohli\England fans put distasteful tweet....jpg
# ./datasets/virat_kohli\England v India_ Virat Kohli faces....jpg
# ./datasets/virat_kohli\Ex-Pakistan captain Salman Butt makes....jpg
# ./datasets/virat_kohli\Former Australia spinner applauds Virat....jpg
# ./datasets/virat_kohli\Great Learning ropes in Virat Kohli as....jpg
# ./datasets/virat_kohli\Holding asks Virat Kohli to _tone down....jpg
# ./datasets/virat_kohli\How Did Virat Kohli Help For COVID....jpeg
# ./datasets/virat_kohli\ICC Awards_ Virat Kohli named ICC Male....jpg
# ./datasets/virat_kohli\In homework_ Virat Kohli_s lesson....jpg
# ./datasets/virat_kohli\India captain Virat Kohli opens up for....webp
# ./datasets/virat_kohli\India captain Virat Kohli....jpg
# ./datasets/virat_kohli\India cricket_ Virat Kohli_s horror....jpg
# ./datasets/virat_kohli\India Vs England _ Time For Virat Kohli....webp
# ./datasets/virat_kohli\International Cricket Council.png
# ./datasets/virat_kohli\IPL 2021_ RCB_ Replacement Players Have....webp
# ./datasets/virat_kohli\Is Virat Kohli the Greatest Of All Time....jpg
# ./datasets/virat_kohli\Meet Virat Kohli_s sister Bhawna Kohli....webp
# ./datasets/virat_kohli\Mind-boggling net worth of Virat Kohli....webp
# ./datasets/virat_kohli\Oval Test_ Virat Kohli breaks Sachin....webp
# ./datasets/virat_kohli\Pat Cummins includes Virat Kohli in his....jpg
# ./datasets/virat_kohli\reach 9000 T20 runs....jpg
# ./datasets/virat_kohli\Records Virat Kohli can break in Test....webp
# ./datasets/virat_kohli\Reports_ ECB turned down Virat Kohli_s....jpg
# ./datasets/virat_kohli\says Virat Kohli after COVID outbreak....jpg
# ./datasets/virat_kohli\Sharing Platform MX Taka Tak.jpg
# ./datasets/virat_kohli\Sports News_The Indian Express.jpg
# ./datasets/virat_kohli\The Board of Control for Cricket in India.png
# ./datasets/virat_kohli\Time_-Virat Kohli Reacts to Shreyas....webp
# ./datasets/virat_kohli\Twitterati react as Virat Kohli....jpg
# ./datasets/virat_kohli\Virat Kohli (1).jpg
# ./datasets/virat_kohli\Virat Kohli - IMDb.jpg
# ./datasets/virat_kohli\Virat Kohli - Wikipedia.jpg
# ./datasets/virat_kohli\Virat Kohli backs _IndiaTogether....webp
# ./datasets/virat_kohli\Virat Kohli Can Win An ICC Trophy_ WV Raman.jpg
# ./datasets/virat_kohli\Virat Kohli completes 10 years in Test....jpeg
# ./datasets/virat_kohli\Virat Kohli e-mailed the BCCI at....webp
# ./datasets/virat_kohli\Virat Kohli Fans Trend _IStandWithVirat....jpg
# ./datasets/virat_kohli\Virat Kohli handing Rohit Sharma India....jpg
# ./datasets/virat_kohli\Virat Kohli hints at Test side overhaul....jpg
# ./datasets/virat_kohli\Virat Kohli Hit By A Mohammed Shami....jpg
# ./datasets/virat_kohli\Virat Kohli is a very powerful guy in....jpg
# ./datasets/virat_kohli\Virat Kohli is in his prime_ will start....jpg
# ./datasets/virat_kohli\Virat Kohli may step down as ODI_ T20....jpg
# ./datasets/virat_kohli\Virat Kohli needs 41 runs in India vs....webp
# ./datasets/virat_kohli\Virat Kohli News_ Latest News and....webp
# ./datasets/virat_kohli\Virat Kohli On Cancelled 5th Test....webp
# ./datasets/virat_kohli\Virat Kohli only Indian in 10 highest....jpg
# ./datasets/virat_kohli\Virat Kohli Profile - ICC Ranking_ Age....jpg
# ./datasets/virat_kohli\Virat Kohli profile and biography... (1).jpg
# ./datasets/virat_kohli\Virat Kohli profile and biography....jpg
# ./datasets/virat_kohli\Virat Kohli Reveals One Of His Aims In....jpg
# ./datasets/virat_kohli\Virat Kohli reveals why he went off the....png
# ./datasets/virat_kohli\Virat Kohli says first Test_s team....jpg
# ./datasets/virat_kohli\Virat Kohli shares inspiring tweet....jpg
# ./datasets/virat_kohli\Virat Kohli to quit as India_s captain....jpg
# ./datasets/virat_kohli\Virat Kohli turns heat on England over....jpg
# ./datasets/virat_kohli\Virat Kohli wicket today_ Watch Kohli....jpg
# ./datasets/virat_kohli\Virat Kohli will end up captaining more... (1).webp
# ./datasets/virat_kohli\Virat Kohli will end up captaining more....webp
# ./datasets/virat_kohli\Virat Kohli will remain captain of all... (1).jpg
# ./datasets/virat_kohli\Virat Kohli will remain captain of all....jpg
# ./datasets/virat_kohli\Virat Kohli _ Stats_ Bio_ Facts and....jpg
# ./datasets/virat_kohli\Virat Kohli-backed Indian fintech....jpg
# ./datasets/virat_kohli\Virat Kohli-backed insurance startup....jpg
# ./datasets/virat_kohli\Virat Kohli.jpg
# ./datasets/virat_kohli\virat kohli_ Family_ failure_ parathas....jpg
# ./datasets/virat_kohli\Virat Kohli_ I am representation of new....jpg
# ./datasets/virat_kohli\Virat Kohli_ Never claimed to be a....jpg
# ./datasets/virat_kohli\Virat Kohli_s earnings & investments....jpg
# ./datasets/virat_kohli\Virat Kohli_s plans undone by England....jpg
# ./datasets/virat_kohli\virat raa.jpg
# ./datasets/virat_kohli\white-ball captain after T20 World Cup....webp
# ./datasets/virat_kohli\white-ball captaincy for Rohit Sharma.jpg
# ./datasets/virat_kohli\WTC final_ Is Virat Kohli battling....webp
# ./datasets/virat_kohli\X-factor_ Virat Kohli expects India....jpg

# %%
import os
celebrity_file_names_dict = {}

folder="./datasets/cropped"
j=-1

for i in os.walk(folder):
    if j==-1:
        lst=i[1]
        j+=1
    else:
        path_to_img=[]
        for l in i[2]:
            path_to_img.append(folder+"/"+lst[j] + "/"+l)
        celebrity_file_names_dict[lst[j]] = path_to_img
        j+=1
celebrity_file_names_dict
# Out:
# {'lionel_messi': ['./datasets/cropped/lionel_messi/lionel_messi1.png',
#   './datasets/cropped/lionel_messi/lionel_messi10.png',
#   './datasets/cropped/lionel_messi/lionel_messi11.png',
#   './datasets/cropped/lionel_messi/lionel_messi12.png',
#   './datasets/cropped/lionel_messi/lionel_messi13.png',
#   './datasets/cropped/lionel_messi/lionel_messi15.png',
#   './datasets/cropped/lionel_messi/lionel_messi16.png',
#   './datasets/cropped/lionel_messi/lionel_messi17.png',
#   './datasets/cropped/lionel_messi/lionel_messi18.png',
#   './datasets/cropped/lionel_messi/lionel_messi19.png',
#   './datasets/cropped/lionel_messi/lionel_messi2.png',
#   './datasets/cropped/lionel_messi/lionel_messi20.png',
#   './datasets/cropped/lionel_messi/lionel_messi21.png',
#   './datasets/cropped/lionel_messi/lionel_messi22.png',
#   './datasets/cropped/lionel_messi/lionel_messi23.png',
#   './datasets/cropped/lionel_messi/lionel_messi24.png',
#   './datasets/cropped/lionel_messi/lionel_messi25.png',
#   './datasets/cropped/lionel_messi/lionel_messi26.png',
#   './datasets/cropped/lionel_messi/lionel_messi27.png',
#   './datasets/cropped/lionel_messi/lionel_messi28.png',
#   './datasets/cropped/lionel_messi/lionel_messi29.png',
#   './datasets/cropped/lionel_messi/lionel_messi3.png',
#   './datasets/cropped/lionel_messi/lionel_messi30.png',
#   './datasets/cropped/lionel_messi/lionel_messi32.png',
#   './datasets/cropped/lionel_messi/lionel_messi33.png',
#   './datasets/cropped/lionel_messi/lionel_messi34.png',
#   './datasets/cropped/lionel_messi/lionel_messi4.png',
#   './datasets/cropped/lionel_messi/lionel_messi5.png',
#   './datasets/cropped/lionel_messi/lionel_messi6.png',
#   './datasets/cropped/lionel_messi/lionel_messi7.png',
#   './datasets/cropped/lionel_messi/lionel_messi8.png',
#   './datasets/cropped/lionel_messi/lionel_messi9.png'],
#  'maria_sharapova': ['./datasets/cropped/maria_sharapova/maria_sharapova1.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova10.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova12.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova13.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova14.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova16.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova17.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova19.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova2.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova20.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova23.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova24.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova25.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova26.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova27.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova28.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova29.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova30.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova31.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova32.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova33.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova34.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova35.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova37.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova4.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova5.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova6.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova7.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova8.png',
#   './datasets/cropped/maria_sharapova/maria_sharapova9.png'],
#  'roger_federer': ['./datasets/cropped/roger_federer/roger_federer1.png',
#   './datasets/cropped/roger_federer/roger_federer10.png',
#   './datasets/cropped/roger_federer/roger_federer11.png',
#   './datasets/cropped/roger_federer/roger_federer12.png',
#   './datasets/cropped/roger_federer/roger_federer14.png',
#   './datasets/cropped/roger_federer/roger_federer15.png',
#   './datasets/cropped/roger_federer/roger_federer16.png',
#   './datasets/cropped/roger_federer/roger_federer17.png',
#   './datasets/cropped/roger_federer/roger_federer18.png',
#   './datasets/cropped/roger_federer/roger_federer19.png',
#   './datasets/cropped/roger_federer/roger_federer2.png',
#   './datasets/cropped/roger_federer/roger_federer20.png',
#   './datasets/cropped/roger_federer/roger_federer21.png',
#   './datasets/cropped/roger_federer/roger_federer22.png',
#   './datasets/cropped/roger_federer/roger_federer23.png',
#   './datasets/cropped/roger_federer/roger_federer3.png',
#   './datasets/cropped/roger_federer/roger_federer4.png',
#   './datasets/cropped/roger_federer/roger_federer6.png',
#   './datasets/cropped/roger_federer/roger_federer7.png',
#   './datasets/cropped/roger_federer/roger_federer8.png',
#   './datasets/cropped/roger_federer/roger_federer9.png'],
#  'serena_williams': ['./datasets/cropped/serena_williams/serena_williams1.png',
#   './datasets/cropped/serena_williams/serena_williams10.png',
#   './datasets/cropped/serena_williams/serena_williams11.png',
#   './datasets/cropped/serena_williams/serena_williams12.png',
#   './datasets/cropped/serena_williams/serena_williams13.png',
#   './datasets/cropped/serena_williams/serena_williams14.png',
#   './datasets/cropped/serena_williams/serena_williams15.png',
#   './datasets/cropped/serena_williams/serena_williams16.png',
#   './datasets/cropped/serena_williams/serena_williams17.png',
#   './datasets/cropped/serena_williams/serena_williams2.png',
#   './datasets/cropped/serena_williams/serena_williams3.png',
#   './datasets/cropped/serena_williams/serena_williams4.png',
#   './datasets/cropped/serena_williams/serena_williams5.png',
#   './datasets/cropped/serena_williams/serena_williams6.png',
#   './datasets/cropped/serena_williams/serena_williams7.png',
#   './datasets/cropped/serena_williams/serena_williams8.png'],
#  'virat_kohli': ['./datasets/cropped/virat_kohli/virat_kohli1.png',
#   './datasets/cropped/virat_kohli/virat_kohli10.png',
#   './datasets/cropped/virat_kohli/virat_kohli11.png',
#   './datasets/cropped/virat_kohli/virat_kohli12.png',
#   './datasets/cropped/virat_kohli/virat_kohli13.png',
#   './datasets/cropped/virat_kohli/virat_kohli14.png',
#   './datasets/cropped/virat_kohli/virat_kohli15.png',
#   './datasets/cropped/virat_kohli/virat_kohli16.png',
#   './datasets/cropped/virat_kohli/virat_kohli17.png',
#   './datasets/cropped/virat_kohli/virat_kohli18.png',
#   './datasets/cropped/virat_kohli/virat_kohli19.png',
#   './datasets/cropped/virat_kohli/virat_kohli2.png',
#   './datasets/cropped/virat_kohli/virat_kohli20.png',
#   './datasets/cropped/virat_kohli/virat_kohli21.png',
#   './datasets/cropped/virat_kohli/virat_kohli22.png',
#   './datasets/cropped/virat_kohli/virat_kohli23.png',
#   './datasets/cropped/virat_kohli/virat_kohli24.png',
#   './datasets/cropped/virat_kohli/virat_kohli25.png',
#   './datasets/cropped/virat_kohli/virat_kohli26.png',
#   './datasets/cropped/virat_kohli/virat_kohli27.png',
#   './datasets/cropped/virat_kohli/virat_kohli28.png',
#   './datasets/cropped/virat_kohli/virat_kohli29.png',
#   './datasets/cropped/virat_kohli/virat_kohli3.png',
#   './datasets/cropped/virat_kohli/virat_kohli30.png',
#   './datasets/cropped/virat_kohli/virat_kohli31.png',
#   './datasets/cropped/virat_kohli/virat_kohli32.png',
#   './datasets/cropped/virat_kohli/virat_kohli33.png',
#   './datasets/cropped/virat_kohli/virat_kohli34.png',
#   './datasets/cropped/virat_kohli/virat_kohli35.png',
#   './datasets/cropped/virat_kohli/virat_kohli36.png',
#   './datasets/cropped/virat_kohli/virat_kohli37.png',
#   './datasets/cropped/virat_kohli/virat_kohli38.png',
#   './datasets/cropped/virat_kohli/virat_kohli39.png',
#   './datasets/cropped/virat_kohli/virat_kohli4.png',
#   './datasets/cropped/virat_kohli/virat_kohli5.png',
#   './datasets/cropped/virat_kohli/virat_kohli6.png',
#   './datasets/cropped/virat_kohli/virat_kohli7.png',
#   './datasets/cropped/virat_kohli/virat_kohli8.png',
#   './datasets/cropped/virat_kohli/virat_kohli9.png']}

# %%
class_dict={}
count=0
for i in celebrity_file_names_dict.keys():
    class_dict[i]=count
    count+=1
class_dict
# Out:
# {'lionel_messi': 0,
#  'maria_sharapova': 1,
#  'roger_federer': 2,
#  'serena_williams': 3,
#  'virat_kohli': 4}

# %%
def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
X,y = [] , []
for celeb_name,celeb_image in celebrity_file_names_dict.items():
    for training in celeb_image:
        img=cv2.imread(training)
        img_scaled=cv2.resize(img,(32,32))
        img_har = w2d(img,'db1',5)
        img_har_scaled = cv2.resize(img_har,(32,32))
        combined_img = np.vstack((img_scaled.reshape(32*32*3,1),img_har_scaled.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celeb_name])

# %%
len(X[0])
# Out:
# 4096

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (138, 4096)

# %% [markdown]
# # Data cleaning process is done now we are ready to train our model

# %%
from sklearn.svm import SVC
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)
pipe = Pipeline([('scaler',StandardScaler()),('svc',SVC(kernel="rbf", C=10))])
pipe.fit(X_train,y_train)
pipe.score(X_test,y_test)
# Out:
# 0.7857142857142857

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.83      0.77         6
#            1       1.00      1.00      1.00         3
#            2       1.00      1.00      1.00         3
#            3       1.00      1.00      1.00         2
#            4       0.92      0.86      0.89        14
#
#     accuracy                           0.89        28
#    macro avg       0.93      0.94      0.93        28
# weighted avg       0.90      0.89      0.89        28

# %% [markdown]
# ### Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn.svm import SVC 
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svc' :{
        'model':SVC(gamma='auto', probability = True),
        'params': {
         'svc__C': [1,10,100,1000],
        'svc__kernel' : ['rbf','linear']
        }
    },
    'random_forest' :{
        'model' : RandomForestClassifier(),
        'params' : {'randomforestclassifier__n_estimators':[1,5,10]
                   }
    },
    'LogisticRegression' : {
        'model' : LogisticRegression(solver='liblinear',multi_class='auto'),
        'params' : { 'logisticregression__C' : [1,5,10]
            
        }
    }
}

# %%
df=[]
best_estimators = {}
for algo,mp in model_params.items():
    pipe = make_pipeline(StandardScaler(),mp['model'])
    clf=GridSearchCV(pipe,mp['params'],cv=5,return_train_score=False)
    clf.fit(X_train,y_train)
    df.append({'model' : algo,
              'params' : clf.best_params_,
              "Score" : clf.best_score_})
    best_estimators[algo] = clf.best_estimator_
    
df=pd.DataFrame(df,columns=['model','params','Score'])
df
# Out:
#                 model                                        params     Score
# 0                 svc          {'svc__C': 10, 'svc__kernel': 'rbf'}  0.736364
# 1       random_forest  {'randomforestclassifier__n_estimators': 10}  0.672727
# 2  LogisticRegression                  {'logisticregression__C': 1}  0.745455

# %%
best_estimators['svc'].score(X_test,y_test)
# Out:
# 0.7857142857142857

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.6785714285714286
